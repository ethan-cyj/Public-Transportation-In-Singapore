# %%
from dotenv import load_dotenv
import pandas as pd
import json
import os 
import numpy as np

# %%
load_dotenv()
# Out:
# True

# %%
directory = os.getcwd()

os.chdir(directory)

# %%
centroid_pairing_df = pd.read_csv(r"..\data\Cluster_data\five_point_Centroid_MRT pairing data fixed.csv")

# %%
centroid_pairing_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
centroid_pairing_df['steepness'] = abs(centroid_pairing_df['steepness'])

centroid_pairing_df['time_difference'] = -centroid_pairing_df['time_difference'] #Reflect time savings as a positive number

# %%
def calculate_weighted_score(dataframe,row1,row2,row3,row4):
    try:
        S = row1 * dataframe["time_difference"] + row2 * dataframe["distance"] + row3 * dataframe["suitability"] + row4 * dataframe["steepness"]
        return S
    except:
        return np.nan

# %%
centroid_pairing_df['weighted_score'] = calculate_weighted_score(centroid_pairing_df,0.4, -0.2, 0.8, -0.1)

# %%
cond = centroid_pairing_df['approximated?'] == 1

centroid_pairing_df[cond].shape
# Out:
# (17, 21)

# %%
centroid_pairing_df.isna().sum()
# Out:
# Latitude_x             0
# Longitude_x            0
# index_x                0
# join_key               0
# MRT.Name               0
# Latitude_y             0
# Longitude_y            0
# index_y                0
# euclidean_distance     0
# coordinate_pair        0
# cycle_route           17
# bus_route              0
# distance               0
# cycle_duration         0
# centroid_name          0
# suitability           18
# steepness             18
# bus_duration           0
# time_difference        0
# approximated?          0
# weighted_score        18
# dtype: int64

# %%
agg_dict = {
    'time_difference': 'mean',
    'distance': 'mean',
    'steepness': 'mean',
    'suitability': 'mean',
    'approximated?': 'sum'
}

df = centroid_pairing_df.groupby('MRT.Name').agg(agg_dict)
df = df.reset_index()

df['Weighted_Score'] = calculate_weighted_score(df, 0.4, -0.2, 0.8, -0.1)

# %%
df
# Out:
#                         MRT.Name  time_difference  distance  steepness  \
# 0          ADMIRALTY MRT STATION         4.003333    0.8134   0.400000
# 1           ALJUNIED MRT STATION         3.650000    0.7636   0.000000
# 2         ANG MO KIO MRT STATION         3.270000    0.8558   0.666667
# 3              BAKAU LRT STATION         3.533333    0.5630   0.000000
# 4            BANGKIT LRT STATION         2.876667    0.8062   0.200000
# ..                           ...              ...       ...        ...
# 170  WOODLANDS SOUTH MRT STATION         6.063333    0.8068   0.000000
# 171        WOODLEIGH MRT STATION         6.610000    0.7284   0.000000
# 172          YEW TEE MRT STATION         2.890000    0.6702   0.800000
# 173     YIO CHU KANG MRT STATION         6.250000    1.3158   0.225020
# 174           YISHUN MRT STATION         5.176667    0.7840   0.000000
#
#      suitability  approximated?  Weighted_Score
# 0       7.631176            0.0        7.503594
# 1       7.053749            0.0        6.950279
# 2       6.392720            2.0        6.184349
# 3       7.506390            0.0        7.305845
# 4       6.197938            0.0        5.927777
# ..           ...            ...             ...
# 170     6.161326            0.0        7.193034
# 171     5.764717            0.0        7.110094
# 172     7.385922            0.0        6.850698
# 173     5.515098            0.0        6.626416
# 174     7.311919            0.0        7.763402
#
# [175 rows x 7 columns]

# %%
mrt_stations_df = pd.read_csv(r"..\data\Cluster_data\mrt_station_final.csv",usecols = [1,2,3])
mrt_stations_df.sort_values(by='MRT.Name', inplace=True)

mrt_stations_df
# Out:
#                         MRT.Name  Latitude   Longitude
# 12         ADMIRALTY MRT STATION  1.440589  103.800990
# 9           ALJUNIED MRT STATION  1.316433  103.882906
# 52        ANG MO KIO MRT STATION  1.369429  103.849455
# 115            BAKAU LRT STATION  1.387994  103.905415
# 54           BANGKIT LRT STATION  1.380022  103.772647
# ..                           ...       ...         ...
# 158  WOODLANDS SOUTH MRT STATION  1.427488  103.792730
# 80         WOODLEIGH MRT STATION  1.339190  103.870818
# 77           YEW TEE MRT STATION  1.397298  103.747358
# 79      YIO CHU KANG MRT STATION  1.381499  103.845171
# 78            YISHUN MRT STATION  1.429443  103.835005
#
# [175 rows x 3 columns]

# %%
mrt_stations_df = pd.merge(mrt_stations_df, df, left_on='MRT.Name',right_on = "MRT.Name",how = "left")

mrt_stations_df.describe()
# Out:
#                         MRT.Name  Latitude   Longitude  time_difference  \
# 0          ADMIRALTY MRT STATION  1.440589  103.800990         4.003333
# 1           ALJUNIED MRT STATION  1.316433  103.882906         3.650000
# 2         ANG MO KIO MRT STATION  1.369429  103.849455         3.270000
# 3              BAKAU LRT STATION  1.387994  103.905415         3.533333
# 4            BANGKIT LRT STATION  1.380022  103.772647         2.876667
# ..                           ...       ...         ...              ...
# 170  WOODLANDS SOUTH MRT STATION  1.427488  103.792730         6.063333
# 171        WOODLEIGH MRT STATION  1.339190  103.870818         6.610000
# 172          YEW TEE MRT STATION  1.397298  103.747358         2.890000
# 173     YIO CHU KANG MRT STATION  1.381499  103.845171         6.250000
# 174           YISHUN MRT STATION  1.429443  103.835005         5.176667
#
#      distance  steepness  suitability  approximated?  Weighted_Score
# 0      0.8134   0.400000     7.631176            0.0        7.503594
# 1      0.7636   0.000000     7.053749            0.0        6.950279
# 2      0.8558   0.666667     6.392720            2.0        6.184349
# 3      0.5630   0.000000     7.506390            0.0        7.305845
# 4      0.8062   0.200000     6.197938            0.0        5.927777
# ..        ...        ...          ...            ...             ...
# 170    0.8068   0.000000     6.161326            0.0        7.193034
# 171    0.7284   0.000000     5.764717            0.0        7.110094
# 172    0.6702   0.800000     7.385922            0.0        6.850698
# 173    1.3158   0.225020     5.515098            0.0        6.626416
# 174    0.7840   0.000000     7.311919            0.0        7.763402
#
# [175 rows x 9 columns]

# %%
mrt_stations_df.describe()
# Out:
#          Latitude   Longitude  time_difference    distance   steepness  \
# count  175.000000  175.000000       175.000000  175.000000  175.000000
# mean     1.345903  103.839643         4.617590    1.225480    0.200003
# std      0.045893    0.065953         4.857827    1.332713    0.237551
# min      1.265389  103.636991       -14.720000    0.416600    0.000000
# 25%      1.307012  103.794565         2.828333    0.714600    0.000000
# 50%      1.339190  103.848649         4.073333    0.870800    0.196469
# 75%      1.385059  103.889302         5.776667    1.159400    0.400000
# max      1.449051  103.987884        33.546667   10.753800    1.000000
#
#        suitability  approximated?  Weighted_Score
# count   175.000000     175.000000      175.000000
# mean      6.790858       0.097143        7.014627
# std       0.619610       0.450725        2.102420
# min       5.434801       0.000000       -2.814775
# 25%       6.362244       0.000000        6.410384
# 50%       6.764457       0.000000        6.950279
# 75%       7.322598       0.000000        7.601777
# max       8.202216       3.000000       18.825533

# %%
ranking = mrt_stations_df.sort_values(by='Weighted_Score',ascending = False)
ranking = ranking.reset_index(drop = True)
ranking['rank'] = ranking.index

ranking
# Out:
#                            MRT.Name  Latitude   Longitude  time_difference  \
# 0        CHANGI AIRPORT MRT STATION  1.357479  103.987884        33.546667
# 1    GARDENS BY THE BAY MRT STATION  1.278487  103.867455        29.670000
# 2              JOO KOON MRT STATION  1.327694  103.678085        17.430000
# 3               PUNGGOL MRT STATION  1.414927  103.910166        12.706667
# 4     MARINA SOUTH PIER MRT STATION  1.271027  103.862448        16.436667
# ..                              ...       ...         ...              ...
# 170               DOVER MRT STATION  1.311405  103.778638        -2.440000
# 171           TUAS LINK MRT STATION  1.340882  103.636991        -9.876667
# 172       TUAS CRESCENT MRT STATION  1.321027  103.649078       -12.996667
# 173          GUL CIRCLE MRT STATION  1.319471  103.660530       -14.503333
# 174      TUAS WEST ROAD MRT STATION  1.329985  103.639617       -14.720000
#
#      distance  steepness  suitability  approximated?  Weighted_Score  rank
# 0      4.8778   0.064148     7.986052            0.0       18.825533     0
# 1      3.4940   0.057370     6.797914            0.0       16.601794     1
# 2      3.2196   0.000000     6.370842            0.0       11.424753     2
# 3      1.4062   0.192515     8.202216            0.0       11.343948     3
# 4      3.5842   0.049921     6.735707            0.0       11.241400     4
# ..        ...        ...          ...            ...             ...   ...
# 170    2.6326   0.013534     6.781917            0.0        3.921660   170
# 171   10.7538   0.000000     6.250349            0.0       -1.101148   171
# 172    7.8296   0.000000     5.987545            0.0       -1.974551   172
# 173    6.8710   0.000000     5.742133            0.0       -2.581827   173
# 174    9.5260   0.000000     6.223032            0.0       -2.814775   174
#
# [175 rows x 10 columns]

# %%
ranking.to_csv("../data/Cluster_data/5_cluster_mrt_ranking.csv", index = False)
